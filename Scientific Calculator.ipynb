# %%
## SCIENTIFIC CALCULATOR:

import math

while True:
    print("\n Choose the math Operation's")
    print("0.Addition")
    print("1.Subtraction")
    print("2.Multiplication")
    print("3.Division")
    print("4.Module")
    print("5.Raising Of Power")
    print("6.Square root")
    print("7.Logarithm")
    print("8.Sine")
    print("9.Cosine")
    print("10.Tangent")

    oper =  input("\n Your Option from Menu")

    # Addition
    if oper == "0":
        val1 = float(input("\n Enter First Value"))
        val2 = float(input("\n Enter Second Value"))

        print("\n The Result is : " + str(val1 + val2) + "\n")
        back = input("\n Go back to the main menu ? (Y/N)")

        if back == 'Y':
            continue
        else:
            break
    # Subtraction
    elif oper == "1":
        val1 = float(input("\n Enter First Value"))
        val2 = float(input("\n Enter Second Value"))

        print("\n The Result is : " + str(val1 - val2) + "\n")
        back = input("\n Go back to the main menu ? (Y/N)")

        if back == 'Y':
            continue
        else:
            break

      # Multiplication
    elif oper == "2":
        val1 = float(input("\n Enter First Value"))
        val2 = float(input("\n Enter Second Value"))

        print("\n The Result is : " + str(val1 * val2) + "\n")
        back = input("\n Go back to the main menu ? (Y/N)")

        if back == 'Y':
            continue
        else:
            break

      # Division
    elif oper == "3":
        val1 = float(input("\n Enter First Value"))
        val2 = float(input("\n Enter Second Value"))

        print("\n The Result is : " + str(val1 / val2) + "\n")
        back = input("\n Go back to the main menu ? (Y/N)")

        if back == 'Y':
            continue
        else:
            break

      #
    elif oper == "4":
        val1 = float(input("\n Enter First Value"))
        val2 = float(input("\n Enter Second Value"))

        print("\n The Result is : " + str(val1 % val2) + "\n")
        back = input("\n Go back to the main menu ? (Y/N)")

        if back == 'Y':
            continue
        else:
            break

      # Raise O f Power
    elif oper == "5":
        val1 = float(input("\n Enter First Value"))
        val2 = float(input("\n Enter Second Value"))

        print("\n The Result is : " + str(math.pow(val1,val2))+ "\n")
        back = input("\n Go back to the main menu ? (Y/N)")

        if back == 'Y':
            continue
        else:
            break
    # Square Root
    elif oper == "6":
        val1 = float(input("\n Enter Value"))
        #val2 = float(input("\n Enter Second Value"))

        print("\n The Result is : " + str(math.sqrt(val1))+ "\n")
        back = input("\n Go back to the main menu ? (Y/N)")

        if back == 'Y':
            continue
        else:
            break
    # Logarithm
    elif oper == "7":
        val1 = float(input("\n Enter First Value"))
        #val2 = float(input("\n Enter Second Value"))

        print("\n The Result is : " + str(math.log(val1))+ "\n")
        back = input("\n Go back to the main menu ? (Y/N)")

        if back == 'Y':
            continue
        else:
            break
    # Sine
    elif oper == "8":
        val1 = float(input("\n Enter First Value"))
        #val2 = float(input("\n Enter Second Value"))

        print("\n The Result is : " + str(math.sin(math.radians(val1))) + "\n")
        back = input("\n Go back to the main menu ? (Y/N)")

        if back == 'Y':
            continue
        else:
            break

    # Cosine
    elif oper == "9":
        val1 = float(input("\n Enter First Value"))
        #val2 = float(input("\n Enter Second Value"))

        print("\n The Result is : " + str(math.cos(math.radians(val1))) + "\n")
        back = input("\n Go back to the main menu ? (Y/N)")

        if back == 'Y':
            continue
        else:
            break
    # Tangent
    elif oper == "10":
        val1 = float(input("\n Enter First Value"))
        #val2 = float(input("\n Enter Second Value"))

        print("\n The Result is : " + str(math.tan(math.radians(val1))) + "\n")
        back = input("\n Go back to the main menu ? (Y/N)")

        if back == 'Y':
            continue
        else:
            break

    # Handling Invalid Data :
    else:
        print("\n Invalid Option ")
        continue
# Out:
#  Choose the math Operation's
# 0.Addition
# 1.Subtraction
# 2.Multiplication
# 3.Division
# 4.Module
# 5.Raising Of Power
# 6.Square root
# 7.Logarithm
# 8.Sine
# 9.Cosine
# 10.Tangent
#
#  Your Option from Menu0
#
#  Enter First Value10
#
#  Enter Second Value5
#
#  The Result is : 15.0
#
#
#  Go back to the main menu ? (Y/N)Y
#
#  Choose the math Operation's
# 0.Addition
# 1.Subtraction
# 2.Multiplication
# 3.Division
# 4.Module
# 5.Raising Of Power
# 6.Square root
# 7.Logarithm
# 8.Sine
# 9.Cosine
# 10.Tangent
#
#  Your Option from Menu1
#
#  Enter First Value10
#
#  Enter Second Value5
#
#  The Result is : 5.0
#
#
#  Go back to the main menu ? (Y/N)Y
#
#  Choose the math Operation's
# 0.Addition
# 1.Subtraction
# 2.Multiplication
# 3.Division
# 4.Module
# 5.Raising Of Power
# 6.Square root
# 7.Logarithm
# 8.Sine
# 9.Cosine
# 10.Tangent
#
#  Your Option from Menu2
#
#  Enter First Value10
#
#  Enter Second Value5
#
#  The Result is : 50.0
#
#
#  Go back to the main menu ? (Y/N)Y
#
#  Choose the math Operation's
# 0.Addition
# 1.Subtraction
# 2.Multiplication
# 3.Division
# 4.Module
# 5.Raising Of Power
# 6.Square root
# 7.Logarithm
# 8.Sine
# 9.Cosine
# 10.Tangent
#
#  Your Option from Menu3
#
#  Enter First Value10
#
#  Enter Second Value5
#
#  The Result is : 2.0
#
#
#  Go back to the main menu ? (Y/N)Y
#
#  Choose the math Operation's
# 0.Addition
# 1.Subtraction
# 2.Multiplication
# 3.Division
# 4.Module
# 5.Raising Of Power
# 6.Square root
# 7.Logarithm
# 8.Sine
# 9.Cosine
# 10.Tangent
#
#  Your Option from MenuY
#
#  Invalid Option
#
#  Choose the math Operation's
# 0.Addition
# 1.Subtraction
# 2.Multiplication
# 3.Division
# 4.Module
# 5.Raising Of Power
# 6.Square root
# 7.Logarithm
# 8.Sine
# 9.Cosine
# 10.Tangent
#
#  Your Option from Menu4
#
#  Enter First Value10
#
#  Enter Second Value3
#
#  The Result is : 1.0
#
#
#  Go back to the main menu ? (Y/N)Y
#
#  Choose the math Operation's
# 0.Addition
# 1.Subtraction
# 2.Multiplication
# 3.Division
# 4.Module
# 5.Raising Of Power
# 6.Square root
# 7.Logarithm
# 8.Sine
# 9.Cosine
# 10.Tangent
#
#  Your Option from Menu5
#
#  Enter First Value2
#
#  Enter Second Value3
#
#  The Result is : 8.0
#
#
#  Go back to the main menu ? (Y/N)Y
#
#  Choose the math Operation's
# 0.Addition
# 1.Subtraction
# 2.Multiplication
# 3.Division
# 4.Module
# 5.Raising Of Power
# 6.Square root
# 7.Logarithm
# 8.Sine
# 9.Cosine
# 10.Tangent
#
#  Your Option from Menu6
#
#  Enter Value3
#
#  The Result is : 1.7320508075688772
#
#
#  Go back to the main menu ? (Y/N)Y
#
#  Choose the math Operation's
# 0.Addition
# 1.Subtraction
# 2.Multiplication
# 3.Division
# 4.Module
# 5.Raising Of Power
# 6.Square root
# 7.Logarithm
# 8.Sine
# 9.Cosine
# 10.Tangent
#
#  Your Option from Menu7
#
#  Enter First Value1
#
#  The Result is : 0.0
#
#
#  Go back to the main menu ? (Y/N)Y
#
#  Choose the math Operation's
# 0.Addition
# 1.Subtraction
# 2.Multiplication
# 3.Division
# 4.Module
# 5.Raising Of Power
# 6.Square root
# 7.Logarithm
# 8.Sine
# 9.Cosine
# 10.Tangent
#
#  Your Option from Menu8
#
#  Enter First Value45
#
#  The Result is : 0.7071067811865476
#
#
#  Go back to the main menu ? (Y/N)Y
#
#  Choose the math Operation's
# 0.Addition
# 1.Subtraction
# 2.Multiplication
# 3.Division
# 4.Module
# 5.Raising Of Power
# 6.Square root
# 7.Logarithm
# 8.Sine
# 9.Cosine
# 10.Tangent
#
#  Your Option from Menu9
#
#  Enter First Value90
#
#  The Result is : 6.123233995736766e-17
#
#
#  Go back to the main menu ? (Y/N)Y
#
#  Choose the math Operation's
# 0.Addition
# 1.Subtraction
# 2.Multiplication
# 3.Division
# 4.Module
# 5.Raising Of Power
# 6.Square root
# 7.Logarithm
# 8.Sine
# 9.Cosine
# 10.Tangent
#
#  Your Option from Menu1O
#
#  Invalid Option
#
#  Choose the math Operation's
# 0.Addition
# 1.Subtraction
# 2.Multiplication
# 3.Division
# 4.Module
# 5.Raising Of Power
# 6.Square root
# 7.Logarithm
# 8.Sine
# 9.Cosine
# 10.Tangent
#
#  Your Option from Menu10
#
#  Enter First Value0
#
#  The Result is : 0.0
#
#
#  Go back to the main menu ? (Y/N)N
